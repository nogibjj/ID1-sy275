# %%
# Notebook for Project 1

import lib

# %% [markdown]
# # Read the data

# %%
dataframe = lib.load_data('data.csv')

# %% [markdown]
# # Describe the data

# %%
lib.display_dataset_head(dataframe)
# Out:
# Dataset Head:
#    Age  Salary  Score
# 0   25   50000     85
# 1   30   55000     89
# 2   35   60000     78
# 3   40   65000     90
# 4   45   70000     82

# %%
print(lib.display_basic_statistics(dataframe))
# Out:
# Basic Descriptive Statistics:
#              Age       Salary      Score
# count   5.000000      5.00000   5.000000
# mean   35.000000  60000.00000  84.800000
# std     7.905694   7905.69415   4.969909
# min    25.000000  50000.00000  78.000000
# 25%    30.000000  55000.00000  82.000000
# 50%    35.000000  60000.00000  85.000000
# 75%    40.000000  65000.00000  89.000000
# max    45.000000  70000.00000  90.000000
#
#
# None

# %%
lib.display_basic_statistics(dataframe)
# Out:
# Basic Descriptive Statistics:
#              Age       Salary      Score
# count   5.000000      5.00000   5.000000
# mean   35.000000  60000.00000  84.800000
# std     7.905694   7905.69415   4.969909
# min    25.000000  50000.00000  78.000000
# 25%    30.000000  55000.00000  82.000000
# 50%    35.000000  60000.00000  85.000000
# 75%    40.000000  65000.00000  89.000000
# max    45.000000  70000.00000  90.000000

# %% [markdown]
# # Visualize the data

# %%
lib.create_visualization(dataframe)
